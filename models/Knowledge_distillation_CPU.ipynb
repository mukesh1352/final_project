# %%
# All Required Imports
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import numpy as np
import time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 import torch.nn as nn
#       4 import torch.nn.functional as F
# ----> 5 from torchvision import datasets, transforms
#       6 from torch.utils.data import DataLoader, TensorDataset
#       7 import matplotlib.pyplot as plt
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torchvision\__init__.py:10
#       7 # Don't re-order these, we need to load the _C extension (done when importing
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#      13     from .version import __version__  # noqa: F401
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torchvision\_meta_registrations.py:25
#      20         return fn
#      22     return wrapper
# ---> 25 @register_meta("roi_align")
#      26 def meta_roi_align(input, rois, spatial_scale, pooled_height, pooled_width, sampling_ratio, aligned):
#      27     torch._check(rois.size(1) == 5, lambda: "rois must have shape as Tensor[K, 5]")
#      28     torch._check(
#      29         input.dtype == rois.dtype,
#      30         lambda: (
#    (...)     33         ),
#      34     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\torchvision\_meta_registrations.py:18, in register_meta.<locals>.wrapper(fn)
#      17 def wrapper(fn):
# ---> 18     if torchvision.extension._has_ops():
#      19         get_meta_lib().impl(getattr(getattr(torch.ops.torchvision, op_name), overload_name), fn)
#      20     return fn
#
# AttributeError: partially initialized module 'torchvision' from 'C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\torchvision\__init__.py' has no attribute 'extension' (most likely due to a circular import)
